# %% [markdown]
# <a href="https://colab.research.google.com/github/MukhtarGhaleb/Test/blob/Child/Untitled9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This is **Ahmed**.
# This is *Nasser*.
# This is ~strikethrough~.

# %% [markdown]
# $\sqrt{3x-1}+(1+x)^2$

# %% [markdown]
# $e^x=\sum_{i=0}^\infty \frac{1}{i!}x^i$
